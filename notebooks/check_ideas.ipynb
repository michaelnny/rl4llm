# %%
import random
import torch

# %%
target_tokens = [520, 690, 338]
batch_size = 8
tokens = torch.tensor(random.choices(target_tokens, k=batch_size))

print(tokens)
# Out:
# tensor([690, 338, 520, 690, 520, 338, 520, 338])
