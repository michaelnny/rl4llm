# %%
from transformers import AutoTokenizer

# %%
model_name = "Qwen/Qwen2.5-0.5B-Instruct"

tokenizer = AutoTokenizer.from_pretrained(model_name)

# %%
full_text = """<think> To determine how much, we can follow these steps:

1. Calculate the total ticket sales.
2. Determine the band's percentage of the total sales.
3. Calculate the band's share of the ticket sales.
4. Divide the band's share of the ticket sales by the number of band members to find out how much each band member gets.
</think>
<answer>Therefore, each band member gets \(\boxed{1837.50}\).</answer>
"""

# %%
token_ids = tokenizer.encode(full_text)

print(token_ids)
# Out:
# [13708, 766, 29, 2014, 8253, 1246, 1753, 11, 582, 646, 1795, 1493, 7354, 1447, 16, 13, 20517, 279, 2790, 11727, 6625, 624, 17, 13, 29901, 279, 7055, 594, 11414, 315, 279, 2790, 6625, 624, 18, 13, 20517, 279, 7055, 594, 4332, 315, 279, 11727, 6625, 624, 19, 13, 62902, 279, 7055, 594, 4332, 315, 279, 11727, 6625, 553, 279, 1372, 315, 7055, 3613, 311, 1477, 700, 1246, 1753, 1817, 7055, 4462, 5221, 624, 522, 26865, 397, 27, 9217, 29, 54815, 11, 1817, 7055, 4462, 5221, 17767, 196, 5131, 291, 90, 16, 23, 18, 22, 13, 20, 15, 11035, 66233, 9217, 397]

# %%
for i in range(0, 10):
    token = tokenizer.decode(token_ids[i:i+1])
    print(token)
# Out:
# <th
# ink
# >
#  To
#  determine
#  how
#  much
# ,
#  we
#  can

# %%
ids = tokenizer.encode("<think>")
print(ids)
# Out:
# [13708, 766, 29]
