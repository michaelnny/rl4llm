# %%
import torch
import random

# %%
import math
print(math.ceil(32 * 0.05))
# Out:
# 2

# %%
N = 32

for i in range(0, N):
    tensor = torch.tensor([0] * N, dtype=torch.float32)

    for j in range(0, i):
        tensor[j] = 1.0
    
    # print(tensor)
    std = tensor.std(unbiased=False)
    print(std)
# Out:
# tensor(0.)
# tensor(0.1740)
# tensor(0.2421)
# tensor(0.2915)
# tensor(0.3307)
# tensor(0.3631)
# tensor(0.3903)
# tensor(0.4134)
# tensor(0.4330)
# tensor(0.4496)
# tensor(0.4635)
# tensor(0.4750)
# tensor(0.4841)
# tensor(0.4911)
# tensor(0.4961)
# tensor(0.4990)
# tensor(0.5000)
# tensor(0.4990)
# tensor(0.4961)
# tensor(0.4911)
# tensor(0.4841)
# tensor(0.4750)
# tensor(0.4635)
# tensor(0.4496)
# tensor(0.4330)
# tensor(0.4134)
# tensor(0.3903)
# tensor(0.3631)
# tensor(0.3307)
# tensor(0.2915)
# tensor(0.2421)
# tensor(0.1740)

# %%
explore_top_k = 30
effective_steps = 5
int(explore_top_k * (0.8**effective_steps))
# Out:
# 9
