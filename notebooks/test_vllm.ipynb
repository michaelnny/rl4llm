# %%
from vllm import LLM, SamplingParams

# Sample prompts.
prompts = [
    "Hello, my name is",
    "The president of the United States is",
    "The capital of France is",
    "The future of AI is",
]
# Create a sampling params object.
sampling_params = SamplingParams(temperature=0.8, top_p=0.95)

# Create an LLM.
llm = LLM(model="facebook/opt-125m", device='cpu')
# Generate texts from the prompts. The output is a list of RequestOutput objects
# that contain the prompt, generated text, and other information.
outputs = llm.generate(prompts, sampling_params)
# Print the outputs.
for output in outputs:
    prompt = output.prompt
    generated_text = output.outputs[0].text
    print(f"Prompt: {prompt!r}, Generated text: {generated_text!r}")
# Out:
# config.json:   0%|          | 0.00/651 [00:00<?, ?B/s]
# INFO 02-13 20:20:15 config.py:510] This model supports multiple tasks: {'classify', 'embed', 'score', 'generate', 'reward'}. Defaulting to 'generate'.
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[2], line 14
#      11 sampling_params = SamplingParams(temperature=0.8, top_p=0.95)
#      13 # Create an LLM.
# ---> 14 llm = LLM(model="facebook/opt-125m", device='cpu')
#      15 # Generate texts from the prompts. The output is a list of RequestOutput objects
#      16 # that contain the prompt, generated text, and other information.
#      17 outputs = llm.generate(prompts, sampling_params)
#
# File ~/.pyenv/versions/3.12.7/lib/python3.12/site-packages/vllm/utils.py:986, in deprecate_args.<locals>.wrapper.<locals>.inner(*args, **kwargs)
#     979             msg += f" {additional_message}"
#     981         warnings.warn(
#     982             DeprecationWarning(msg),
#     983             stacklevel=3,  # The inner function takes up one level
#     984         )
# --> 986 return fn(*args, **kwargs)
#
# File ~/.pyenv/versions/3.12.7/lib/python3.12/site-packages/vllm/entrypoints/llm.py:230, in LLM.__init__(self, model, tokenizer, tokenizer_mode, skip_tokenizer_init, trust_remote_code, allowed_local_media_path, tensor_parallel_size, dtype, quantization, revision, tokenizer_revision, seed, gpu_memory_utilization, swap_space, cpu_offload_gb, enforce_eager, max_seq_len_to_capture, disable_custom_all_reduce, disable_async_output_proc, hf_overrides, mm_processor_kwargs, task, override_pooler_config, compilation_config, **kwargs)
#     227 self.engine_class = self.get_engine_class()
#     229 # TODO(rob): enable mp by default (issue with fork vs spawn)
# --> 230 self.llm_engine = self.engine_class.from_engine_args(
#     231     engine_args, usage_context=UsageContext.LLM_CLASS)
#     233 self.request_counter = Counter()
#
# File ~/.pyenv/versions/3.12.7/lib/python3.12/site-packages/vllm/engine/llm_engine.py:514, in LLMEngine.from_engine_args(cls, engine_args, usage_context, stat_loggers)
#     512 """Creates an LLM engine from the engine arguments."""
#     513 # Create the engine configs.
# --> 514 engine_config = engine_args.create_engine_config(usage_context)
#     515 executor_class = cls._get_executor_cls(engine_config)
#     516 # Create the LLM engine.
#
# File ~/.pyenv/versions/3.12.7/lib/python3.12/site-packages/vllm/engine/arg_utils.py:1238, in EngineArgs.create_engine_config(self, usage_context)
#    1227         raise ValueError(
#    1228             f"Invalid module {m} in collect_detailed_traces. "
#    1229             f"Valid modules are {ALLOWED_DETAILED_TRACE_MODULES}")
#    1230 observability_config = ObservabilityConfig(
#    1231     otlp_traces_endpoint=self.otlp_traces_endpoint,
#    1232     collect_model_forward_time="model" in detailed_trace_modules
#    (...)
#    1235     or "all" in detailed_trace_modules,
#    1236 )
# -> 1238 config = VllmConfig(
#    1239     model_config=model_config,
#    1240     cache_config=cache_config,
#    1241     parallel_config=parallel_config,
#    1242     scheduler_config=scheduler_config,
#    1243     device_config=device_config,
#    1244     lora_config=lora_config,
#    1245     speculative_config=speculative_config,
#    1246     load_config=load_config,
#    1247     decoding_config=decoding_config,
#    1248     observability_config=observability_config,
#    1249     prompt_adapter_config=prompt_adapter_config,
#    1250     compilation_config=self.compilation_config,
#    1251     kv_transfer_config=self.kv_transfer_config,
#    1252 )
#    1254 if envs.VLLM_USE_V1:
#    1255     self._override_v1_engine_config(config)
#
# File <string>:18, in __init__(self, model_config, cache_config, parallel_config, scheduler_config, device_config, load_config, lora_config, speculative_config, decoding_config, observability_config, prompt_adapter_config, quant_config, compilation_config, kv_transfer_config, instance_id)
#
# File ~/.pyenv/versions/3.12.7/lib/python3.12/site-packages/vllm/config.py:3096, in VllmConfig.__post_init__(self)
#    3093 """Verify configs are valid & consistent with each other.
#    3094 """
#    3095 if self.model_config is not None:
# -> 3096     self.model_config.verify_async_output_proc(self.parallel_config,
#    3097                                                self.speculative_config,
#    3098                                                self.device_config)
#    3099     self.model_config.verify_with_parallel_config(self.parallel_config)
#    3101 if self.cache_config is not None:
#
# File ~/.pyenv/versions/3.12.7/lib/python3.12/site-packages/vllm/config.py:641, in ModelConfig.verify_async_output_proc(self, parallel_config, speculative_config, device_config)
#     637     return
#     639 # Reminder: Please update docs/source/usage/compatibility_matrix.md
#     640 # If the feature combo become valid
# --> 641 if not current_platform.is_async_output_supported(self.enforce_eager):
#     642     logger.warning(
#     643         "Async output processing is not supported on the "
#     644         "current platform type %s.", current_platform.device_type)
#     645     self.use_async_output_proc = False
#
# File ~/.pyenv/versions/3.12.7/lib/python3.12/site-packages/vllm/platforms/interface.py:165, in Platform.is_async_output_supported(cls, enforce_eager)
#     160 @classmethod
#     161 def is_async_output_supported(cls, enforce_eager: Optional[bool]) -> bool:
#     162     """
#     163     Check if the current platform supports async output.
#     164     """
# --> 165     raise NotImplementedError
#
# NotImplementedError:
